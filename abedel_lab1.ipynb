# %% [markdown]
# <h1>Adam Bedel<br>
# Ners590 Lab 1<br>
# 8/28/2024

# %%
#Basic␣Packages
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# <h4><b>Exercise Set 1<b>

# %%
# Exercise Set 1 (a)
def is_prime(n):
  if n <= 1:
    return False
  for i in range(2, n): # Could make this faster
    if n%i == 0:
      return False
  return True

# Test Function
print(is_prime(11))
# Out:
# True

# %%
# Exercise Set 1 (b)
class Rectangle:
  def __init__(self, width=0, height=0):
    self.width = width
    self.height = height
  def area(self):
    return self.width * self.height * 1.0
  def perimeter(self):
    return 2.0 * (self.width + self.height)
  def diagonal(self):
    return np.sqrt(self.width**2 + self.height**2)

# Test Function
myRectangle = Rectangle(3, 4)
print("My rectangle has an area of %d, perimeter of %d, and diagonal of %d. " \
      % (myRectangle.area(), myRectangle.perimeter(), myRectangle.diagonal()))
# Out:
# My rectangle has an area of 12, perimeter of 14, and diagonal of 5.

# %%
# Exercise Set 1 (c)
def create_grade_dict(names, grades):
  newDict = {}
  for name in names:
    newDict[name] = grades[names.index(name)]
  return newDict

# Test Function
names = ['Alice', 'Bob', 'Charlie']
grades = [85, 92, 78]
print(create_grade_dict(names, grades))
# Out:
# {'Alice': 85, 'Bob': 92, 'Charlie': 78}

# %%
# Exercise Set 1 (d)

# For 1-n, create empty str and update with 'Fizz' or 'Buzz' as necessary.
# If string remains empty, just print current number instead
def fizz_buzz(n):
  for i in range(1, n+1):
    string = ''
    if i % 3 == 0:
      string = 'Fizz'
    if i % 5 == 0:
      string = string + 'Buzz'
    print(string if string else i)

  # Test Function
fizz_buzz(15)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz

# %%
# Exercise Set 1 (e)
def nested_average(data):
  newDict = {}
  for key in data.keys():
    newDict[key] = np.mean(data[key])
  return newDict

# Test Function
scores = {'Math': [90, 85, 88], 'Science': [78, 82, 91],'English': [85, 87, 89]}
print(nested_average(scores))
# Out:
# {'Math': 87.66666666666667, 'Science': 83.66666666666667, 'English': 87.0}

# %%
# Exercise Set 1 (f)
vec=[1,2,3,4,5,10,11,12,13,14,18,20,22,25,30]

print("Length is", len(vec))
print("6th element is %d and 11th is %d" % (vec[5], vec[10]))
print("Last element is", vec[-1])
# Out:
# Length is 15
# 6th element is 10 and 11th is 18
# Last element is 30

# %% [markdown]
# <h4><b>Exercise Set 2<b>

# %%
# Exercise Set 2 (a)
url = 'https://raw.githubusercontent.com/aims-umich/ners590data/main/boston.csv'
data = pd.read_csv(url)

# %%
# Exercise Set 2 (b)
print(data.head(5))
data.describe()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    LSTAT  MEDV
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# ...

# %%
# Exercise Set 2 (c)
print(data.iloc[:,2])
print('\n--------------------------------------------------\n')
print(data.iloc[99:105,:])
print('\n--------------------------------------------------\n')
print(data.iloc[99:105,4:7])
# Out:
# 0       2.31
# 1       7.07
# 2       7.07
# 3       2.18
# 4       2.18
#        ...
# 501    11.93
# 502    11.93
# 503    11.93
# 504    11.93
# 505    11.93
# Name: INDUS, Length: 506, dtype: float64
#
# --------------------------------------------------
#
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 99   0.06860  0.0   2.89     0  0.445  7.416  62.5  3.4952    2  276     18.0
# 100  0.14866  0.0   8.56     0  0.520  6.727  79.9  2.7778    5  384     20.9
# 101  0.11432  0.0   8.56     0  0.520  6.781  71.3  2.8561    5  384     20.9
# 102  0.22876  0.0   8.56     0  0.520  6.405  85.4  2.7147    5  384     20.9
# 103  0.21161  0.0   8.56     0  0.520  6.137  87.4  2.7147    5  384     20.9
# 104  0.13960  0.0   8.56     0  0.520  6.167  90.0  2.4210    5  384     20.9
#
#      LSTAT  MEDV
# 99    6.19  33.2
# 100   9.42  27.5
# 101   7.67  26.5
# 102  10.63  18.6
# 103  13.44  19.3
# 104  12.33  20.1
#
# ...

# %%
# Exercise Set 2 (d)

# filter data by bool
filtered_data = data[data['MEDV'] > 30]

# Sort and print
sorted_homes = filtered_data.sort_values('RM')
print(sorted_homes.head(10))
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE      DIS  RAD  TAX  \
# 368  4.89822   0.0  18.10     0  0.631  4.970  100.0   1.3325   24  666
# 372  8.26725   0.0  18.10     1  0.668  5.875   89.6   1.1296   24  666
# 181  0.06888   0.0   2.46     0  0.488  6.144   62.2   2.5979    3  193
# 371  9.23230   0.0  18.10     0  0.631  6.216  100.0   1.1691   24  666
# 229  0.44178   0.0   6.20     0  0.504  6.552   21.4   3.3751    8  307
# 183  0.10008   0.0   2.46     0  0.488  6.563   95.6   2.8470    3  193
# 39   0.02763  75.0   2.95     0  0.428  6.595   21.8   5.4011    3  252
# 223  0.61470   0.0   6.20     0  0.507  6.618   80.8   3.2721    8  307
# 369  5.66998   0.0  18.10     1  0.631  6.683   96.8   1.3567   24  666
# 353  0.01709  90.0   2.02     0  0.410  6.728   36.1  12.1265    5  187
#
#      PTRATIO  LSTAT  MEDV
# 368     20.2   3.26  50.0
# 372     20.2   8.88  50.0
# 181     17.8   9.45  36.2
# 371     20.2   9.53  50.0
# 229     17.4   3.76  31.5
# ...

# %%
# Exercise Set 2 (e)

# If PRICE_PER_ROOM does not exist, create it
if 'PRICE_PER_ROOM' not in data.columns:
  data.insert(data.shape[1], 'PRICE_PER_ROOM', \
              data.loc[:, 'MEDV'] / data.loc[:, 'RM'])

print(data.iloc[0:10,:])
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#    LSTAT  MEDV  PRICE_PER_ROOM
# 0   4.98  24.0        3.650190
# 1   9.14  21.6        3.363962
# ...

# %%
# Exercise Set 2 (f)
plt.scatter(data.loc[:,'RM'], data.loc[:,'MEDV'])
plt.xlabel('Number of Rooms')
plt.ylabel('Median Value')
plt.show()

# %%
# Exercise Set 2 (g)

# If HIGH_VALUE does not exist, create it
if 'HIGH_VALUE' not in data.columns:
  median_value = data.median().loc['MEDV']
  data.insert(data.shape[1], 'HIGH_VALUE', data.loc[:,'MEDV'] > median_value)

print(data.iloc[0:10,:])
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#    LSTAT  MEDV  PRICE_PER_ROOM  HIGH_VALUE
# 0   4.98  24.0        3.650190        True
# ...

# %%
# Exercise Set 2 (h)
correlation_matrix = data.corr()

# To find which columns are most highly correlated with MEDV, just
# inspect the correlation matrix below (RM, LSTAT, and our own columns)

# I think a diverging color palette works better here
sns.heatmap(correlation_matrix, annot = True, fmt = '.1f') #, cmap = 'vlag', \
            #vmin = -1.0, vmax = 1.0)
# Out:
# <Axes: >

# %% [markdown]
# <h4><b>Exercise Set 3<b>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
